# %% [markdown]
# <a href="https://colab.research.google.com/github/kondyskrzysiek/API/blob/master/121_130_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
#
# ### Spis treści:
# * [Import biblioteki](#0)
# * [Ćwiczenie 121](#1)
# * [Ćwiczenie 122](#2)
# * [Ćwiczenie 123](#3)
# * [Ćwiczenie 124](#4)
# * [Ćwiczenie 125](#5)
# * [Ćwiczenie 126](#6)
# * [Ćwiczenie 127](#7)
# * [Ćwiczenie 128](#8)
# * [Ćwiczenie 129](#9)
# * [Ćwiczenie 130](#10)

# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set()
np.__version__
# Out:
# '1.21.5'

# %% [markdown]
# Funkcja _fetch_financial_data()_ pobiera dane dotyczące notowań spółek giełdowych. Będzie wykorzystywana w poniższych ćwiczeniach. Aby pobrać dane konkretnej spółki należy przekazać odpowiedni ticker (symbol) spółki.
#
# Kilka przykładowych tickerów spółek:
# * AMZN - Amazon
# * GOOGL - Google
# * MSFT - Microsoft
# * AAPL - Apple
# * NKE - Nike
# * WMT - Walmart

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 121
# Wykorzystując funkcję _fetch_financial_data()_ pobierz notowania dla spółki Google (Alphabet) i przypisz do zmiennej _google_. Wyświetl obiekt _google_.

# %%
google = fetch_financial_data(company='GOOGL')
google
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2022-03-08 2525.00 2625.00 2513.49 2542.09  2014479
# 2022-03-07 2629.76 2634.70 2525.90 2527.57  2255647
# 2022-03-04 2658.55 2677.03 2606.75 2638.13  1522532
# 2022-03-03 2720.20 2728.79 2660.51 2677.99  1230162
# 2022-03-02 2692.56 2705.25 2661.43 2691.43  1175990
# ...            ...     ...     ...     ...      ...
# 2017-03-15  867.94  869.88  861.29  868.39  1332885
# 2017-03-14  863.75  867.58  860.13  865.91  1061692
# 2017-03-13  865.68  867.13  860.82  864.58  1166605
# 2017-03-10  862.70  864.23  857.61  861.40  1296760
# 2017-03-09  853.69  860.71  852.67  857.84  1240728
#
# [1259 rows x 5 columns]

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 122
# Wyświetl podstawowe informacje na temat obiektu _google_.

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2022-03-08 to 2017-03-09
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1259 non-null   float64
#  1   High    1259 non-null   float64
#  2   Low     1259 non-null   float64
#  3   Close   1259 non-null   float64
#  4   Volume  1259 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.0 KB

# %% [markdown]
# Wyświetl podstawowe statystyki o obiekcie _google_.

# %%
pd.set_option('precision',2)
google.describe()
# Out:
#           Open     High      Low    Close    Volume
# count  1259.00  1259.00  1259.00  1259.00  1.26e+03
# mean   1510.78  1525.69  1495.58  1511.09  1.76e+06
# std     615.53   620.96   608.84   614.74  8.16e+05
# min     828.09   841.38   824.30   835.15  4.66e+05
# 25%    1083.51  1094.76  1070.44  1084.05  1.25e+06
# 50%    1223.47  1236.24  1213.64  1222.73  1.54e+06
# 75%    1748.63  1767.83  1734.26  1752.45  2.00e+06
# max    3025.00  3030.93  2977.98  2996.77  6.66e+06

# %% [markdown]
# Zwróć uwagę na precyzję zapisu poszczególnych statystyk.
# Spróbuj ustawić odpowiednie opcje biblioteki _pandas_, tak aby wyświetlać dane z dokładnością do dwóch miejsc po przecinku.
#
# __Wskazówka:__
# https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html

# %%
pd.options.display.float_format = '{:.2f}'.format
google.describe()
# Out:
#          Open    High     Low   Close     Volume
# count 1259.00 1259.00 1259.00 1259.00    1259.00
# mean  1510.78 1525.69 1495.58 1511.09 1757670.38
# std    615.53  620.96  608.84  614.74  815620.04
# min    828.09  841.38  824.30  835.15  465638.00
# 25%   1083.51 1094.76 1070.44 1084.05 1246224.50
# 50%   1223.47 1236.24 1213.64 1222.73 1543238.00
# 75%   1748.63 1767.83 1734.26 1752.45 2002741.00
# max   3025.00 3030.93 2977.98 2996.77 6658855.00

# %% [markdown]
# __Dodatkowo:__
# Poniższe ustawienie stłumi także notację wykładniczą (patrz kolumna _Volume_).

# %%
pd.options.display.float_format = '{:.2f}'.format
google.describe()
# Out:
#          Open    High     Low   Close     Volume
# count 1259.00 1259.00 1259.00 1259.00    1259.00
# mean  1510.78 1525.69 1495.58 1511.09 1757670.38
# std    615.53  620.96  608.84  614.74  815620.04
# min    828.09  841.38  824.30  835.15  465638.00
# 25%   1083.51 1094.76 1070.44 1084.05 1246224.50
# 50%   1223.47 1236.24 1213.64 1222.73 1543238.00
# 75%   1748.63 1767.83 1734.26 1752.45 2002741.00
# max   3025.00 3030.93 2977.98 2996.77 6658855.00

# %% [markdown]
# Zbuduj wykres ceny zamknięcia (_Close_) dla obiektu _google_.

# %%
google['Close'].plot()

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 123
# Zamień indeks _Date_ na kolumnę. Przypisz trwale zmiany do zniennej _google_.

# %%
google = google.reset_index()
google
# Out:
#            Date    Open    High     Low   Close   Volume
# 0    2022-03-08 2525.00 2625.00 2513.49 2542.09  2014479
# 1    2022-03-07 2629.76 2634.70 2525.90 2527.57  2255647
# 2    2022-03-04 2658.55 2677.03 2606.75 2638.13  1522532
# 3    2022-03-03 2720.20 2728.79 2660.51 2677.99  1230162
# 4    2022-03-02 2692.56 2705.25 2661.43 2691.43  1175990
# ...         ...     ...     ...     ...     ...      ...
# 1254 2017-03-15  867.94  869.88  861.29  868.39  1332885
# 1255 2017-03-14  863.75  867.58  860.13  865.91  1061692
# 1256 2017-03-13  865.68  867.13  860.82  864.58  1166605
# 1257 2017-03-10  862.70  864.23  857.61  861.40  1296760
# 1258 2017-03-09  853.69  860.71  852.67  857.84  1240728
#
# [1259 rows x 6 columns]

# %% [markdown]
# Przypisz dwie nowe kolumny do obiektu _google_ dodając kolumnę z aktualnym numerem miesiąca o nazwie _'Month'_ oraz z rokiem o nazwie _'Year'_.

# %%
google['Month'] = google['Date'].dt.month
google['Year'] = google['Date'].dt.year

# %%
google
# Out:
#            Date    Open    High     Low   Close   Volume  Month  Year
# 0    2022-03-08 2525.00 2625.00 2513.49 2542.09  2014479      3  2022
# 1    2022-03-07 2629.76 2634.70 2525.90 2527.57  2255647      3  2022
# 2    2022-03-04 2658.55 2677.03 2606.75 2638.13  1522532      3  2022
# 3    2022-03-03 2720.20 2728.79 2660.51 2677.99  1230162      3  2022
# 4    2022-03-02 2692.56 2705.25 2661.43 2691.43  1175990      3  2022
# ...         ...     ...     ...     ...     ...      ...    ...   ...
# 1254 2017-03-15  867.94  869.88  861.29  868.39  1332885      3  2017
# 1255 2017-03-14  863.75  867.58  860.13  865.91  1061692      3  2017
# 1256 2017-03-13  865.68  867.13  860.82  864.58  1166605      3  2017
# 1257 2017-03-10  862.70  864.23  857.61  861.40  1296760      3  2017
# 1258 2017-03-09  853.69  860.71  852.67  857.84  1240728      3  2017
#
# [1259 rows x 8 columns]

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 124
# Policz średnią cenę zamknięcia (_Close_) dla poszczególnego roku (pogrupuj dane po roku - kolumna _Year_ i następnie policz wartość średnią).

# %%
google.groupby('Year')['Close'].mean()
# Out:
# Year
# 2017    962.48
# 2018   1122.05
# 2019   1191.22
# 2020   1478.99
# 2021   2484.50
# 2022   2713.20
# Name: Close, dtype: float64

# %% [markdown]
# Otrzymane wartości przedstaw na wykresie wykorzystując metodę _plot()_.

# %%
google.groupby('Year')['Close'].mean().plot()

# %% [markdown]
# Policz średnią cenę zamknięcia (_Close_) dla miesiąca (pogrupuj dane po miesiącu - kolumna _Month_ i następnie policz wartość średnią).

# %%
google.groupby('Month')['Close'].mean()
# Out:
# Month
# 1    1621.34
# 2    1693.71
# 3    1375.43
# 4    1336.22
# 5    1358.70
# 6    1420.24
# 7    1482.95
# 8    1526.55
# 9    1553.43
# 10   1521.49
# 11   1620.77
# 12   1652.97
# Name: Close, dtype: float64

# %% [markdown]
# Otrzymane wartości przedstaw na wykresie wykorzystując metodę _plot()_.
# Zauważ, które miesiące mogą wskazywać na słabsze okresy na giełdzie.

# %%
google.groupby('Month')['Close'].mean().plot()

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 125
# Pogrupuj dane z obiektu _google_ na poziomie roku i miesiąca. Następnie policz wartość średnią.

# %%
google.groupby(['Year','Month'])['Close'].mean()
# Out:
# Year  Month
# 2017  3        854.67
#       4        861.38
#       5        961.65
#       6        973.37
#       7        963.44
#                 ...
# 2021  11      2935.13
#       12      2903.02
# 2022  1       2719.24
#       2       2734.26
#       3       2626.41
# Name: Close, Length: 61, dtype: float64

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 126
# Znajdź indeks dla którego kolumna _Close_ przyjmuje wartość największą.

# %%
google['Close'].argmax()
# Out:
# 74

# %% [markdown]
# Wytnij wiersz dla tego indeksu z obiektu _google_ jako obiekt DataFrame. Odczytaj datę.

# %%
google.iloc[[google['Close'].argmax()]]
# Out:
#          Date    Open    High     Low   Close   Volume  Month  Year
# 74 2021-11-18 2964.83 3011.61 2957.69 2996.77  1781411     11  2021

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 127
# Z obiektu _google_ wytnij kolumny _Date_, _Open_, _Close_, _Volume_.
# Nie zmieniaj pierwotnego obiektu _google_!

# %%
google[['Date','Open','Close','Volume']]
# Out:
#            Date    Open   Close   Volume
# 0    2022-03-08 2525.00 2542.09  2014479
# 1    2022-03-07 2629.76 2527.57  2255647
# 2    2022-03-04 2658.55 2638.13  1522532
# 3    2022-03-03 2720.20 2677.99  1230162
# 4    2022-03-02 2692.56 2691.43  1175990
# ...         ...     ...     ...      ...
# 1254 2017-03-15  867.94  868.39  1332885
# 1255 2017-03-14  863.75  865.91  1061692
# 1256 2017-03-13  865.68  864.58  1166605
# 1257 2017-03-10  862.70  861.40  1296760
# 1258 2017-03-09  853.69  857.84  1240728
#
# [1259 rows x 4 columns]

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 128
# Ustaw z powrotem indeks dla kolumny _Date_. Wyświetl obiekt _google_.

# %%
google = google.set_index('Date')

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 129
# Usuń na stałe kolumny _Year_ i _Month_ z obiektu _google_. Wyświetl obiekt _google_.

# %%
google = google.drop(columns=['Month','Year'])

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 130
# Przypisz polskie nazwy kolumn (bez polskich znaków):
# * Open -> Otwarcie
# * High -> Najwyzszy
# * Low -> Najnizszy
# * Close -> Zamkniecie
# * Volume -> Wolumen
#
# do obiektu _google_. Wyświetl obiekt _google_.

# %%
google.columns = ['Otwarcie','Najwyzszy','Najnizszy','Zamkniecie','Wolumen']

# %%
google
# Out:
#             Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# Date
# 2022-03-08   2525.00    2625.00    2513.49     2542.09  2014479
# 2022-03-07   2629.76    2634.70    2525.90     2527.57  2255647
# 2022-03-04   2658.55    2677.03    2606.75     2638.13  1522532
# 2022-03-03   2720.20    2728.79    2660.51     2677.99  1230162
# 2022-03-02   2692.56    2705.25    2661.43     2691.43  1175990
# ...              ...        ...        ...         ...      ...
# 2017-03-15    867.94     869.88     861.29      868.39  1332885
# 2017-03-14    863.75     867.58     860.13      865.91  1061692
# 2017-03-13    865.68     867.13     860.82      864.58  1166605
# 2017-03-10    862.70     864.23     857.61      861.40  1296760
# 2017-03-09    853.69     860.71     852.67      857.84  1240728
#
# [1259 rows x 5 columns]
